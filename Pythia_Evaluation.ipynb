# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# %cd lm-evaluation-harness
# !pip install -e .
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 32530, done.
# remote: Counting objects: 100% (5900/5900), done.
# remote: Compressing objects: 100% (681/681), done.
# remote: Total 32530 (delta 5617), reused 5248 (delta 5219), pack-reused 26630
# Receiving objects: 100% (32530/32530), 22.56 MiB | 9.64 MiB/s, done.
# Resolving deltas: 100% (22947/22947), done.
# /content/lm-evaluation-harness
# Obtaining file:///content/lm-evaluation-harness
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting accelerate>=0.21.0 (from lm_eval==0.4.2)
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 7.3 MB/s eta 0:00:00
# Collecting evaluate (from lm_eval==0.4.2)
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 14.4 MB/s eta 0:00:00
# Collecting datasets>=2.16.0 (from lm_eval==0.4.2)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 52.4 MB/s eta 0:00:00
# Collecting jsonlines (from lm_eval==0.4.2)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (2.9.0)
# Collecting peft>=0.2.0 (from lm_eval==0.4.2)
#   Downloading peft-0.10.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 27.1 MB/s eta 0:00:00
# Collecting pybind11>=2.6.2 (from lm_eval==0.4.2)
#   Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 30.3 MB/s eta 0:00:00
# Collecting pytablewriter (from lm_eval==0.4.2)
#   Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 18.8 MB/s eta 0:00:00
# Collecting rouge-score>=0.0.4 (from lm_eval==0.4.2)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==0.4.2)
#   Downloading sacrebleu-2.4.1-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (1.2.2)
# Collecting sqlitedict (from lm_eval==0.4.2)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (2.2.1+cu121)
# Collecting tqdm-multiprocess (from lm_eval==0.4.2)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (4.38.2)
# Collecting zstandard (from lm_eval==0.4.2)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 96.5 MB/s eta 0:00:00
# Collecting dill (from lm_eval==0.4.2)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 19.3 MB/s eta 0:00:00
# Collecting word2number (from lm_eval==0.4.2)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2) (10.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (4.66.2)
# Collecting xxhash (from datasets>=2.16.0->lm_eval==0.4.2)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 29.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.16.0->lm_eval==0.4.2)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2) (3.9.3)
# Collecting responses<0.19 (from evaluate->lm_eval==0.4.2)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2) (1.16.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==0.4.2)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==0.4.2)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2) (4.9.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 63.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 93.0 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.3 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.8 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.5 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->lm_eval==0.4.2)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.3 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.2) (0.15.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==0.4.2) (23.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2) (67.7.2)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm_eval==0.4.2)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==0.4.2)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==0.4.2)
#   Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==0.4.2)
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==0.4.2)
#   Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.3.2 (from pytablewriter->lm_eval==0.4.2)
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.2) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.2) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.2) (2023.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.2) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.2) (8.1.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==0.4.2) (1.3.0)
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict, word2number
#   Building editable for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.2-0.editable-py3-none-any.whl size=15185 sha256=495602ff41579305bb2fb47e49d858b865eda48947c4c5f265d6b0fa8971f89a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e12iy8zt/wheels/dc/8d/a0/ce1a137b6a29fcf5007da91566ee423695e01d20703991091d
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=9d8702028fcfbab9e5fef37ec03b1ecebf80389d5c5a66bb3c05ddcb0e8e2c6b
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=61be9c02d5cb9d88f1e10f0b618fccf3e8aa758c85a2c67f459c5e6453818c12
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5566 sha256=3a51eb766944c7093fa8257985bae4b420488ab77061ccae6f1efa5a6afc970c
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built lm_eval rouge-score sqlitedict word2number
# Installing collected packages: word2number, sqlitedict, zstandard, xxhash, tcolorpy, pybind11, portalocker, pathvalidate, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mbstrdecoder, jsonlines, dill, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, responses, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, DataProperty, tabledata, evaluate, accelerate, pytablewriter, peft, lm_eval
# Successfully installed DataProperty-1.0.1 accelerate-0.28.0 colorama-0.4.6 datasets-2.18.0 dill-0.3.8 evaluate-0.4.1 jsonlines-4.0.0 lm_eval-0.4.2 mbstrdecoder-1.1.3 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 pathvalidate-3.2.0 peft-0.10.0 portalocker-2.8.2 pybind11-2.11.1 pytablewriter-1.2.0 responses-0.18.0 rouge-score-0.1.2 sacrebleu-2.4.1 sqlitedict-2.1.0 tabledata-1.3.3 tcolorpy-0.1.4 tqdm-multiprocess-0.0.11 typepy-1.3.2 word2number-1.1 xxhash-3.4.1 zstandard-0.22.0

# %% [markdown]
# # Pythia-410m

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-410m \
    --tasks truthfulqa_mc1 \
    --device cuda:0 \
    --batch_size 8
# Out:
# 2024-03-26 06:29:44.379967: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 06:29:44.380023: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 06:29:44.382008: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-26 06:29:45.640679: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading builder script: 100% 5.67k/5.67k [00:00<00:00, 20.6MB/s]
# 2024-03-26:06:29:52,304 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-26:06:29:58,221 INFO     [__main__.py:335] Selected Tasks: ['truthfulqa_mc1']
# 2024-03-26:06:29:58,226 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-26:06:29:58,226 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'EleutherAI/pythia-410m'}
# 2024-03-26:06:29:58,290 INFO     [huggingface.py:163] Using device 'cuda:0'
# config.json: 100% 570/570 [00:00<00:00, 3.00MB/s]
# model.safetensors: 100% 911M/911M [00:58<00:00, 15.6MB/s]
# tokenizer_config.json: 100% 396/396 [00:00<00:00, 2.24MB/s]
# tokenizer.json: 100% 2.11M/2.11M [00:00<00:00, 2.86MB/s]
# special_tokens_map.json: 100% 99.0/99.0 [00:00<00:00, 547kB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading readme: 100% 9.59k/9.59k [00:00<00:00, 28.0MB/s]
# Downloading data: 100% 271k/271k [00:00<00:00, 1.03MB/s]
# Generating validation split: 100% 817/817 [00:00<00:00, 25653.72 examples/s]
# 2024-03-26:06:31:11,597 INFO     [task.py:395] Building contexts for truthfulqa_mc1 on rank 0...
# 100% 817/817 [00:01<00:00, 675.68it/s]
# 2024-03-26:06:31:12,868 INFO     [evaluator.py:379] Running loglikelihood requests
# Running loglikelihood requests: 100% 4114/4114 [00:17<00:00, 241.52it/s]
# hf (pretrained=EleutherAI/pythia-410m), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# |    Tasks     |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |--------------|------:|------|-----:|------|-----:|---|-----:|
# |truthfulqa_mc1|      2|none  |     0|acc   |0.2375|±  |0.0149|

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-410m \
    --tasks mmlu \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size 8
# Out:
# 2024-03-26 06:31:41.144037: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 06:31:41.144092: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 06:31:41.145716: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-26 06:31:42.436496: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-26:06:31:47,026 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-26:06:31:53,007 INFO     [__main__.py:335] Selected Tasks: ['mmlu']
# 2024-03-26:06:31:53,009 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-26:06:31:53,009 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'EleutherAI/pythia-410m'}
# 2024-03-26:06:31:53,053 INFO     [huggingface.py:163] Using device 'cuda:0'
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 24.6MB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 7.74MB/s]
# Downloading data: 100% 166M/166M [00:01<00:00, 94.9MB/s]
# Generating test split: 235 examples [00:00, 2286.79 examples/s]
# Generating validation split: 26 examples [00:00, 6748.26 examples/s]
# Generating dev split: 5 examples [00:00, 45.85 examples/s]
# Generating test split: 310 examples [00:00, 3095.37 examples/s]
# Generating validation split: 32 examples [00:00, 3538.75 examples/s]
# Generating dev split: 5 examples [00:00, 56.29 examples/s]
# Generating test split: 100 examples [00:00, 1107.36 examples/s]
# Generating validation split: 8 examples [00:00, 1554.67 examples/s]
# Generating dev split: 5 examples [00:00, 57.26 examples/s]
# Generating test split: 378 examples [00:00, 3583.90 examples/s]
# Generating validation split: 41 examples [00:00, 6078.27 examples/s]
# Generating dev split: 5 examples [00:00, 57.14 examples/s]
# Generating test split: 100 examples [00:00, 1101.01 examples/s]
# Generating validation split: 11 examples [00:00, 2284.14 examples/s]
# Generating dev split: 5 examples [00:00, 58.35 examples/s]
# Generating test split: 152 examples [00:00, 1752.35 examples/s]
# Generating validation split: 16 examples [00:00, 5082.46 examples/s]
# Generating dev split: 5 examples [00:00, 58.23 examples/s]
# Generating test split: 144 examples [00:00, 1647.03 examples/s]
# Generating validation split: 16 examples [00:00, 2979.97 examples/s]
# Generating dev split: 5 examples [00:00, 58.26 examples/s]
# Generating test split: 100 examples [00:00, 1053.89 examples/s]
# Generating validation split: 11 examples [00:00, 2810.51 examples/s]
# Generating dev split: 5 examples [00:00, 58.75 examples/s]
# Generating test split: 270 examples [00:00, 2836.07 examples/s]
# Generating validation split: 29 examples [00:00, 6505.93 examples/s]
# Generating dev split: 5 examples [00:00, 57.68 examples/s]
# Generating test split: 203 examples [00:00, 2113.74 examples/s]
# Generating validation split: 22 examples [00:00, 4052.47 examples/s]
# Generating dev split: 5 examples [00:00, 56.44 examples/s]
# Generating test split: 151 examples [00:00, 1609.27 examples/s]
# Generating validation split: 17 examples [00:00, 3845.91 examples/s]
# Generating dev split: 5 examples [00:00, 58.05 examples/s]
# Generating test split: 102 examples [00:00, 1127.52 examples/s]
# Generating validation split: 11 examples [00:00, 3332.90 examples/s]
# Generating dev split: 5 examples [00:00, 58.61 examples/s]
# Generating test split: 100 examples [00:00, 1137.12 examples/s]
# Generating validation split: 9 examples [00:00, 2999.03 examples/s]
# Generating dev split: 5 examples [00:00, 58.45 examples/s]
# Generating test split: 100 examples [00:00, 1129.16 examples/s]
# Generating validation split: 11 examples [00:00, 2366.75 examples/s]
# Generating dev split: 5 examples [00:00, 57.56 examples/s]
# Generating test split: 112 examples [00:00, 1284.86 examples/s]
# Generating validation split: 11 examples [00:00, 3249.11 examples/s]
# Generating dev split: 5 examples [00:00, 55.68 examples/s]
# Generating test split: 100 examples [00:00, 1124.73 examples/s]
# Generating validation split: 11 examples [00:00, 3136.89 examples/s]
# Generating dev split: 5 examples [00:00, 56.99 examples/s]
# Generating test split: 145 examples [00:00, 1594.14 examples/s]
# Generating validation split: 16 examples [00:00, 4029.11 examples/s]
# Generating dev split: 5 examples [00:00, 55.11 examples/s]
# Generating test split: 216 examples [00:00, 2278.18 examples/s]
# Generating validation split: 23 examples [00:00, 4849.39 examples/s]
# Generating dev split: 5 examples [00:00, 55.92 examples/s]
# Generating test split: 135 examples [00:00, 1495.92 examples/s]
# Generating validation split: 14 examples [00:00, 4256.32 examples/s]
# Generating dev split: 5 examples [00:00, 57.70 examples/s]
# Generating test split: 100 examples [00:00, 1135.00 examples/s]
# Generating validation split: 10 examples [00:00, 3163.60 examples/s]
# Generating dev split: 5 examples [00:00, 56.75 examples/s]
# Generating test split: 272 examples [00:00, 2659.18 examples/s]
# Generating validation split: 31 examples [00:00, 5203.64 examples/s]
# Generating dev split: 5 examples [00:00, 57.14 examples/s]
# Generating test split: 306 examples [00:00, 3163.81 examples/s]
# Generating validation split: 33 examples [00:00, 6145.91 examples/s]
# Generating dev split: 5 examples [00:00, 57.74 examples/s]
# Generating test split: 103 examples [00:00, 1172.37 examples/s]
# Generating validation split: 11 examples [00:00, 2490.54 examples/s]
# Generating dev split: 5 examples [00:00, 56.87 examples/s]
# Generating test split: 783 examples [00:00, 6013.29 examples/s]
# Generating validation split: 86 examples [00:00, 11483.93 examples/s]
# Generating dev split: 5 examples [00:00, 57.02 examples/s]
# Generating test split: 282 examples [00:00, 2807.14 examples/s]
# Generating validation split: 31 examples [00:00, 4552.80 examples/s]
# Generating dev split: 5 examples [00:00, 58.90 examples/s]
# Generating test split: 234 examples [00:00, 2480.17 examples/s]
# Generating validation split: 25 examples [00:00, 4540.47 examples/s]
# Generating dev split: 5 examples [00:00, 58.62 examples/s]
# Generating test split: 223 examples [00:00, 2365.03 examples/s]
# Generating validation split: 23 examples [00:00, 4128.25 examples/s]
# Generating dev split: 5 examples [00:00, 58.37 examples/s]
# Generating test split: 100 examples [00:00, 1158.77 examples/s]
# Generating validation split: 11 examples [00:00, 3635.44 examples/s]
# Generating dev split: 5 examples [00:00, 58.52 examples/s]
# Generating test split: 265 examples [00:00, 2719.17 examples/s]
# Generating validation split: 29 examples [00:00, 6281.82 examples/s]
# Generating dev split: 5 examples [00:00, 58.58 examples/s]
# Generating test split: 166 examples [00:00, 1857.55 examples/s]
# Generating validation split: 18 examples [00:00, 3723.86 examples/s]
# Generating dev split: 5 examples [00:00, 59.26 examples/s]
# Generating test split: 173 examples [00:00, 1896.84 examples/s]
# Generating validation split: 22 examples [00:00, 5136.64 examples/s]
# Generating dev split: 5 examples [00:00, 59.38 examples/s]
# Generating test split: 100 examples [00:00, 956.16 examples/s]
# Generating validation split: 11 examples [00:00, 3585.15 examples/s]
# Generating dev split: 5 examples [00:00, 59.87 examples/s]
# Generating test split: 198 examples [00:00, 2091.88 examples/s]
# Generating validation split: 22 examples [00:00, 6418.22 examples/s]
# Generating dev split: 5 examples [00:00, 58.96 examples/s]
# Generating test split: 100 examples [00:00, 1109.97 examples/s]
# Generating validation split: 11 examples [00:00, 2856.45 examples/s]
# Generating dev split: 5 examples [00:00, 58.91 examples/s]
# Generating test split: 245 examples [00:00, 2614.88 examples/s]
# Generating validation split: 27 examples [00:00, 3988.53 examples/s]
# Generating dev split: 5 examples [00:00, 58.82 examples/s]
# Generating test split: 110 examples [00:00, 1258.50 examples/s]
# Generating validation split: 12 examples [00:00, 2541.49 examples/s]
# Generating dev split: 5 examples [00:00, 58.72 examples/s]
# Generating test split: 238 examples [00:00, 2433.69 examples/s]
# Generating validation split: 26 examples [00:00, 4421.86 examples/s]
# Generating dev split: 5 examples [00:00, 56.11 examples/s]
# Generating test split: 193 examples [00:00, 2143.33 examples/s]
# Generating validation split: 21 examples [00:00, 5450.86 examples/s]
# Generating dev split: 5 examples [00:00, 59.41 examples/s]
# Generating test split: 612 examples [00:00, 5331.17 examples/s]
# Generating validation split: 69 examples [00:00, 8179.27 examples/s]
# Generating dev split: 5 examples [00:00, 57.50 examples/s]
# Generating test split: 114 examples [00:00, 1325.02 examples/s]
# Generating validation split: 12 examples [00:00, 3206.86 examples/s]
# Generating dev split: 5 examples [00:00, 58.12 examples/s]
# Generating test split: 545 examples [00:00, 4953.86 examples/s]
# Generating validation split: 60 examples [00:00, 7591.50 examples/s]
# Generating dev split: 5 examples [00:00, 57.43 examples/s]
# Generating test split: 201 examples [00:00, 2235.31 examples/s]
# Generating validation split: 22 examples [00:00, 3732.95 examples/s]
# Generating dev split: 5 examples [00:00, 59.60 examples/s]
# Generating test split: 390 examples [00:00, 3765.31 examples/s]
# Generating validation split: 43 examples [00:00, 7256.29 examples/s]
# Generating dev split: 5 examples [00:00, 58.36 examples/s]
# Generating test split: 131 examples [00:00, 1478.19 examples/s]
# Generating validation split: 12 examples [00:00, 2640.83 examples/s]
# Generating dev split: 5 examples [00:00, 57.84 examples/s]
# Generating test split: 171 examples [00:00, 1882.85 examples/s]
# Generating validation split: 19 examples [00:00, 4577.88 examples/s]
# Generating dev split: 5 examples [00:00, 58.36 examples/s]
# Generating test split: 126 examples [00:00, 1401.72 examples/s]
# Generating validation split: 14 examples [00:00, 3347.22 examples/s]
# Generating dev split: 5 examples [00:00, 59.12 examples/s]
# Generating test split: 346 examples [00:00, 3341.78 examples/s]
# Generating validation split: 38 examples [00:00, 5294.78 examples/s]
# Generating dev split: 5 examples [00:00, 58.08 examples/s]
# Generating test split: 895 examples [00:00, 6602.28 examples/s]
# Generating validation split: 100 examples [00:00, 10675.52 examples/s]
# Generating dev split: 5 examples [00:00, 51.52 examples/s]
# Generating test split: 163 examples [00:00, 1803.35 examples/s]
# Generating validation split: 18 examples [00:00, 3642.47 examples/s]
# Generating dev split: 5 examples [00:00, 59.57 examples/s]
# Generating test split: 237 examples [00:00, 2312.27 examples/s]
# Generating validation split: 26 examples [00:00, 3689.92 examples/s]
# Generating dev split: 5 examples [00:00, 57.77 examples/s]
# Generating test split: 204 examples [00:00, 2101.02 examples/s]
# Generating validation split: 22 examples [00:00, 3363.27 examples/s]
# Generating dev split: 5 examples [00:00, 57.83 examples/s]
# Generating test split: 1534 examples [00:00, 8131.40 examples/s]
# Generating validation split: 170 examples [00:00, 10996.28 examples/s]
# Generating dev split: 5 examples [00:00, 57.72 examples/s]
# Generating test split: 324 examples [00:00, 3131.19 examples/s]
# Generating validation split: 35 examples [00:00, 6035.71 examples/s]
# Generating dev split: 5 examples [00:00, 58.40 examples/s]
# Generating test split: 121 examples [00:00, 1369.72 examples/s]
# Generating validation split: 13 examples [00:00, 3049.21 examples/s]
# Generating dev split: 5 examples [00:00, 59.64 examples/s]
# Generating test split: 311 examples [00:00, 3158.27 examples/s]
# Generating validation split: 34 examples [00:00, 7675.26 examples/s]
# Generating dev split: 5 examples [00:00, 58.25 examples/s]
# Generating test split: 108 examples [00:00, 1221.11 examples/s]
# Generating validation split: 11 examples [00:00, 2061.45 examples/s]
# Generating dev split: 5 examples [00:00, 58.35 examples/s]
# Generating test split: 165 examples [00:00, 1814.46 examples/s]
# Generating validation split: 18 examples [00:00, 2912.26 examples/s]
# Generating dev split: 5 examples [00:00, 60.50 examples/s]
# 2024-03-26:06:36:55,042 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 5
# 2024-03-26:06:36:55,042 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_jurisprudence from None to 5
# 2024-03-26:06:36:55,042 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_philosophy from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_international_law from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_prehistory from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_law from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_disputes from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_formal_logic from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_world_religions from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_sexuality from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_sociology from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_econometrics from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_psychology from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_public_relations from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_security_studies from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_geography from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_business_ethics from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_medicine from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_virology from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_medical_genetics from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_aging from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_marketing from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_accounting from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_miscellaneous from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_management from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_nutrition from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_medicine from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_global_facts from None to 5
# 2024-03-26:06:36:55,043 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-26:06:36:55,044 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-26:06:36:55,049 INFO     [task.py:395] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:02<00:00, 65.38it/s]
# 2024-03-26:06:36:57,582 INFO     [task.py:395] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:01<00:00, 66.05it/s]
# 2024-03-26:06:36:59,223 INFO     [task.py:395] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:04<00:00, 65.97it/s]
# 2024-03-26:06:37:03,952 INFO     [task.py:395] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:01<00:00, 65.98it/s]
# 2024-03-26:06:37:05,793 INFO     [task.py:395] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:04<00:00, 66.13it/s]
# 2024-03-26:06:37:10,707 INFO     [task.py:395] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:23<00:00, 66.08it/s]
# 2024-03-26:06:37:33,993 INFO     [task.py:395] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:03<00:00, 65.60it/s]
# 2024-03-26:06:37:37,114 INFO     [task.py:395] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:03<00:00, 66.11it/s]
# 2024-03-26:06:37:40,711 INFO     [task.py:395] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:02<00:00, 66.25it/s]
# 2024-03-26:06:37:43,180 INFO     [task.py:395] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:13<00:00, 66.34it/s]
# 2024-03-26:06:37:56,713 INFO     [task.py:395] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:05<00:00, 66.17it/s]
# 2024-03-26:06:38:01,960 INFO     [task.py:395] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:01<00:00, 66.17it/s]
# 2024-03-26:06:38:03,871 INFO     [task.py:395] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:02<00:00, 65.79it/s]
# 2024-03-26:06:38:06,479 INFO     [task.py:395] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:01<00:00, 66.28it/s]
# 2024-03-26:06:38:08,463 INFO     [task.py:395] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:05<00:00, 66.22it/s]
# 2024-03-26:06:38:14,371 INFO     [task.py:395] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:03<00:00, 66.39it/s]
# 2024-03-26:06:38:17,409 INFO     [task.py:395] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:08<00:00, 66.18it/s]
# 2024-03-26:06:38:25,669 INFO     [task.py:395] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:01<00:00, 66.31it/s]
# 2024-03-26:06:38:27,395 INFO     [task.py:395] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:09<00:00, 66.12it/s]
# 2024-03-26:06:38:36,679 INFO     [task.py:395] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:02<00:00, 65.52it/s]
# 2024-03-26:06:38:39,634 INFO     [task.py:395] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:03<00:00, 65.73it/s]
# 2024-03-26:06:38:43,269 INFO     [task.py:395] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:01<00:00, 66.43it/s]
# 2024-03-26:06:38:44,932 INFO     [task.py:395] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:03<00:00, 66.45it/s]
# 2024-03-26:06:38:48,631 INFO     [task.py:395] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:01<00:00, 66.58it/s]
# 2024-03-26:06:38:50,138 INFO     [task.py:395] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:02<00:00, 66.16it/s]
# 2024-03-26:06:38:53,141 INFO     [task.py:395] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:01<00:00, 64.08it/s]
# 2024-03-26:06:38:54,707 INFO     [task.py:395] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:02<00:00, 66.08it/s]
# 2024-03-26:06:38:57,334 INFO     [task.py:395] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:02<00:00, 66.44it/s]
# 2024-03-26:06:38:59,841 INFO     [task.py:395] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:03<00:00, 66.28it/s]
# 2024-03-26:06:39:03,852 INFO     [task.py:395] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:01<00:00, 65.38it/s]
# 2024-03-26:06:39:05,387 INFO     [task.py:395] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:03<00:00, 60.63it/s]
# 2024-03-26:06:39:09,076 INFO     [task.py:395] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:03<00:00, 65.73it/s]
# 2024-03-26:06:39:12,648 INFO     [task.py:395] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:04<00:00, 65.74it/s]
# 2024-03-26:06:39:16,951 INFO     [task.py:395] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:11<00:00, 66.15it/s]
# 2024-03-26:06:39:28,824 INFO     [task.py:395] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:01<00:00, 65.80it/s]
# 2024-03-26:06:39:30,395 INFO     [task.py:395] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:04<00:00, 66.33it/s]
# 2024-03-26:06:39:35,023 INFO     [task.py:395] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:04<00:00, 66.19it/s]
# 2024-03-26:06:39:39,145 INFO     [task.py:395] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:01<00:00, 66.25it/s]
# 2024-03-26:06:39:40,660 INFO     [task.py:395] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:02<00:00, 65.83it/s]
# 2024-03-26:06:39:42,718 INFO     [task.py:395] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 66.09it/s]
# 2024-03-26:06:39:45,997 INFO     [task.py:395] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 65.78it/s]
# 2024-03-26:06:39:48,208 INFO     [task.py:395] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 66.13it/s]
# 2024-03-26:06:39:49,726 INFO     [task.py:395] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 66.05it/s]
# 2024-03-26:06:39:51,428 INFO     [task.py:395] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 66.29it/s]
# 2024-03-26:06:39:52,942 INFO     [task.py:395] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.28it/s]
# 2024-03-26:06:39:54,456 INFO     [task.py:395] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 66.30it/s]
# 2024-03-26:06:39:56,000 INFO     [task.py:395] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 66.19it/s]
# 2024-03-26:06:39:58,289 INFO     [task.py:395] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:03<00:00, 65.72it/s]
# 2024-03-26:06:40:01,388 INFO     [task.py:395] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:04<00:00, 66.46it/s]
# 2024-03-26:06:40:05,465 INFO     [task.py:395] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 66.26it/s]
# 2024-03-26:06:40:06,980 INFO     [task.py:395] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 66.02it/s]
# 2024-03-26:06:40:09,168 INFO     [task.py:395] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 66.07it/s]
# 2024-03-26:06:40:11,477 INFO     [task.py:395] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 65.53it/s]
# 2024-03-26:06:40:13,008 INFO     [task.py:395] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 66.11it/s]
# 2024-03-26:06:40:18,744 INFO     [task.py:395] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 66.21it/s]
# 2024-03-26:06:40:20,260 INFO     [task.py:395] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 65.84it/s]
# 2024-03-26:06:40:24,984 INFO     [task.py:395] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 66.22it/s]
# 2024-03-26:06:40:28,545 INFO     [evaluator.py:379] Running loglikelihood requests
# Running loglikelihood requests: 100% 56168/56168 [03:36<00:00, 259.89it/s]
# hf (pretrained=EleutherAI/pythia-410m), gen_kwargs: (None), limit: None, num_fewshot: 5, batch_size: 8
# |                 Tasks                 |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |---------------------------------------|-------|------|-----:|------|-----:|---|-----:|
# |mmlu                                   |N/A    |none  |     0|acc   |0.2674|±  |0.0037|
# | - humanities                          |N/A    |none  |     5|acc   |0.2448|±  |0.0063|
# |  - formal_logic                       |      0|none  |     5|acc   |0.3254|±  |0.0419|
# |  - high_school_european_history       |      0|none  |     5|acc   |0.2424|±  |0.0335|
# |  - high_school_us_history             |      0|none  |     5|acc   |0.2794|±  |0.0315|
# |  - high_school_world_history          |      0|none  |     5|acc   |0.2236|±  |0.0271|
# |  - international_law                  |      0|none  |     5|acc   |0.3554|±  |0.0437|
# |  - jurisprudence                      |      0|none  |     5|acc   |0.2130|±  |0.0396|
# |  - logical_fallacies                  |      0|none  |     5|acc   |0.2699|±  |0.0349|
# |  - moral_disputes                     |      0|none  |     5|acc   |0.2543|±  |0.0234|
# |  - moral_scenarios                    |      0|none  |     5|acc   |0.2190|±  |0.0138|
# |  - philosophy                         |      0|none  |     5|acc   |0.2444|±  |0.0244|
# |  - prehistory                         |      0|none  |     5|acc   |0.2315|±  |0.0235|
# |  - professional_law                   |      0|none  |     5|acc   |0.2405|±  |0.0109|
# |  - world_religions                    |      0|none  |     5|acc   |0.2749|±  |0.0342|
# | - other                               |N/A    |none  |     5|acc   |0.2646|±  |0.0078|
# |  - business_ethics                    |      0|none  |     5|acc   |0.2600|±  |0.0441|
# |  - clinical_knowledge                 |      0|none  |     5|acc   |0.2642|±  |0.0271|
# |  - college_medicine                   |      0|none  |     5|acc   |0.2139|±  |0.0313|
# |  - global_facts                       |      0|none  |     5|acc   |0.1800|±  |0.0386|
# |  - human_aging                        |      0|none  |     5|acc   |0.2287|±  |0.0282|
# |  - management                         |      0|none  |     5|acc   |0.2524|±  |0.0430|
# |  - marketing                          |      0|none  |     5|acc   |0.2009|±  |0.0262|
# |  - medical_genetics                   |      0|none  |     5|acc   |0.3300|±  |0.0473|
# |  - miscellaneous                      |      0|none  |     5|acc   |0.2490|±  |0.0155|
# |  - nutrition                          |      0|none  |     5|acc   |0.2680|±  |0.0254|
# |  - professional_accounting            |      0|none  |     5|acc   |0.2376|±  |0.0254|
# |  - professional_medicine              |      0|none  |     5|acc   |0.4485|±  |0.0302|
# |  - virology                           |      0|none  |     5|acc   |0.2892|±  |0.0353|
# | - social_sciences                     |N/A    |none  |     5|acc   |0.2902|±  |0.0081|
# |  - econometrics                       |      0|none  |     5|acc   |0.2281|±  |0.0395|
# |  - high_school_geography              |      0|none  |     5|acc   |0.2778|±  |0.0319|
# |  - high_school_government_and_politics|      0|none  |     5|acc   |0.2332|±  |0.0305|
# |  - high_school_macroeconomics         |      0|none  |     5|acc   |0.3513|±  |0.0242|
# |  - high_school_microeconomics         |      0|none  |     5|acc   |0.2521|±  |0.0282|
# |  - high_school_psychology             |      0|none  |     5|acc   |0.3211|±  |0.0200|
# |  - human_sexuality                    |      0|none  |     5|acc   |0.2443|±  |0.0377|
# |  - professional_psychology            |      0|none  |     5|acc   |0.2712|±  |0.0180|
# |  - public_relations                   |      0|none  |     5|acc   |0.2273|±  |0.0401|
# |  - security_studies                   |      0|none  |     5|acc   |0.4041|±  |0.0314|
# |  - sociology                          |      0|none  |     5|acc   |0.2338|±  |0.0299|
# |  - us_foreign_policy                  |      0|none  |     5|acc   |0.2600|±  |0.0441|
# | - stem                                |N/A    |none  |     5|acc   |0.2816|±  |0.0079|
# |  - abstract_algebra                   |      0|none  |     5|acc   |0.2700|±  |0.0446|
# |  - anatomy                            |      0|none  |     5|acc   |0.3037|±  |0.0397|
# |  - astronomy                          |      0|none  |     5|acc   |0.2039|±  |0.0328|
# |  - college_biology                    |      0|none  |     5|acc   |0.2778|±  |0.0375|
# |  - college_chemistry                  |      0|none  |     5|acc   |0.3900|±  |0.0490|
# |  - college_computer_science           |      0|none  |     5|acc   |0.3300|±  |0.0473|
# |  - college_mathematics                |      0|none  |     5|acc   |0.3100|±  |0.0465|
# |  - college_physics                    |      0|none  |     5|acc   |0.2451|±  |0.0428|
# |  - computer_security                  |      0|none  |     5|acc   |0.1900|±  |0.0394|
# |  - conceptual_physics                 |      0|none  |     5|acc   |0.2638|±  |0.0288|
# |  - electrical_engineering             |      0|none  |     5|acc   |0.2345|±  |0.0353|
# |  - elementary_mathematics             |      0|none  |     5|acc   |0.2302|±  |0.0217|
# |  - high_school_biology                |      0|none  |     5|acc   |0.3097|±  |0.0263|
# |  - high_school_chemistry              |      0|none  |     5|acc   |0.2463|±  |0.0303|
# |  - high_school_computer_science       |      0|none  |     5|acc   |0.3000|±  |0.0461|
# |  - high_school_mathematics            |      0|none  |     5|acc   |0.2630|±  |0.0268|
# |  - high_school_physics                |      0|none  |     5|acc   |0.2914|±  |0.0371|
# |  - high_school_statistics             |      0|none  |     5|acc   |0.4722|±  |0.0340|
# |  - machine_learning                   |      0|none  |     5|acc   |0.2321|±  |0.0401|
#
# |      Groups      |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |------------------|-------|------|-----:|------|-----:|---|-----:|
# |mmlu              |N/A    |none  |     0|acc   |0.2674|±  |0.0037|
# | - humanities     |N/A    |none  |     5|acc   |0.2448|±  |0.0063|
# | - other          |N/A    |none  |     5|acc   |0.2646|±  |0.0078|
# | - social_sciences|N/A    |none  |     5|acc   |0.2902|±  |0.0081|
# | - stem           |N/A    |none  |     5|acc   |0.2816|±  |0.0079|

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-410m \
    --tasks ai2_arc \
    --device cuda:0 \
    --batch_size 8

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-410m  \
    --tasks winogrande \
    --device cuda:0 \
    --batch_size 8

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-410m  \
    --tasks lambada \
    --device cuda:0 \
    --batch_size 8

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-410m \
    --tasks hellaswag \
    --device cuda:0 \
    --batch_size 8

# %% [markdown]
# # Pythia-1.4b

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-1.4b \
    --tasks truthfulqa_mc1 \
    --device cuda:0 \
    --batch_size 8
# Out:
# 2024-03-26 06:47:59.266453: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 06:47:59.266509: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 06:47:59.268118: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-26 06:48:00.529705: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-26:06:48:05,205 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-26:06:48:11,133 INFO     [__main__.py:335] Selected Tasks: ['truthfulqa_mc1']
# 2024-03-26:06:48:11,134 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-26:06:48:11,134 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'EleutherAI/pythia-1.4b'}
# 2024-03-26:06:48:11,184 INFO     [huggingface.py:163] Using device 'cuda:0'
# config.json: 100% 570/570 [00:00<00:00, 2.96MB/s]
# model.safetensors: 100% 2.93G/2.93G [03:22<00:00, 14.5MB/s]
# tokenizer_config.json: 100% 396/396 [00:00<00:00, 1.66MB/s]
# tokenizer.json: 100% 2.11M/2.11M [00:00<00:00, 50.6MB/s]
# special_tokens_map.json: 100% 99.0/99.0 [00:00<00:00, 578kB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-03-26:06:51:44,655 INFO     [task.py:395] Building contexts for truthfulqa_mc1 on rank 0...
# 100% 817/817 [00:01<00:00, 674.56it/s]
# 2024-03-26:06:51:45,927 INFO     [evaluator.py:379] Running loglikelihood requests
# Running loglikelihood requests: 100% 4114/4114 [00:20<00:00, 204.49it/s]
# hf (pretrained=EleutherAI/pythia-1.4b), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# |    Tasks     |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |--------------|------:|------|-----:|------|-----:|---|-----:|
# |truthfulqa_mc1|      2|none  |     0|acc   |0.2289|±  |0.0147|

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-1.4b \
    --tasks mmlu \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size 8
# Out:
# 2024-03-26 06:52:16.278342: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 06:52:16.278398: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 06:52:16.280036: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-26 06:52:17.546601: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-26:06:52:22,086 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-26:06:52:27,876 INFO     [__main__.py:335] Selected Tasks: ['mmlu']
# 2024-03-26:06:52:27,877 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-26:06:52:27,877 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'EleutherAI/pythia-1.4b'}
# 2024-03-26:06:52:27,923 INFO     [huggingface.py:163] Using device 'cuda:0'
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_jurisprudence from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_philosophy from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_international_law from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_prehistory from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_law from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_disputes from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_formal_logic from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_world_religions from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_sexuality from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_sociology from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_econometrics from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_psychology from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_public_relations from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_security_studies from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_geography from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_business_ethics from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_medicine from None to 5
# 2024-03-26:06:55:58,138 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_virology from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_medical_genetics from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_aging from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_marketing from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_accounting from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_miscellaneous from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_management from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_nutrition from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_medicine from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_global_facts from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-26:06:55:58,139 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-26:06:55:58,144 INFO     [task.py:395] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:02<00:00, 65.44it/s]
# 2024-03-26:06:56:00,674 INFO     [task.py:395] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:01<00:00, 66.08it/s]
# 2024-03-26:06:56:02,314 INFO     [task.py:395] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:04<00:00, 66.62it/s]
# 2024-03-26:06:56:06,997 INFO     [task.py:395] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:01<00:00, 65.93it/s]
# 2024-03-26:06:56:08,838 INFO     [task.py:395] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:04<00:00, 65.22it/s]
# 2024-03-26:06:56:13,821 INFO     [task.py:395] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:23<00:00, 65.75it/s]
# 2024-03-26:06:56:37,221 INFO     [task.py:395] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:03<00:00, 65.63it/s]
# 2024-03-26:06:56:40,340 INFO     [task.py:395] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:03<00:00, 65.80it/s]
# 2024-03-26:06:56:43,955 INFO     [task.py:395] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:02<00:00, 65.00it/s]
# 2024-03-26:06:56:46,471 INFO     [task.py:395] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:13<00:00, 65.75it/s]
# 2024-03-26:06:57:00,124 INFO     [task.py:395] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:05<00:00, 65.96it/s]
# 2024-03-26:06:57:05,387 INFO     [task.py:395] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:01<00:00, 65.86it/s]
# 2024-03-26:06:57:07,307 INFO     [task.py:395] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:02<00:00, 65.32it/s]
# 2024-03-26:06:57:09,934 INFO     [task.py:395] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:01<00:00, 66.00it/s]
# 2024-03-26:06:57:11,926 INFO     [task.py:395] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:05<00:00, 65.87it/s]
# 2024-03-26:06:57:17,864 INFO     [task.py:395] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:03<00:00, 65.22it/s]
# 2024-03-26:06:57:20,957 INFO     [task.py:395] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:08<00:00, 65.81it/s]
# 2024-03-26:06:57:29,263 INFO     [task.py:395] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:01<00:00, 64.66it/s]
# 2024-03-26:06:57:31,033 INFO     [task.py:395] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:09<00:00, 65.85it/s]
# 2024-03-26:06:57:40,355 INFO     [task.py:395] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:02<00:00, 65.25it/s]
# 2024-03-26:06:57:43,323 INFO     [task.py:395] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:03<00:00, 65.98it/s]
# 2024-03-26:06:57:46,941 INFO     [task.py:395] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:01<00:00, 66.38it/s]
# 2024-03-26:06:57:48,604 INFO     [task.py:395] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:03<00:00, 65.91it/s]
# 2024-03-26:06:57:52,333 INFO     [task.py:395] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:01<00:00, 64.66it/s]
# 2024-03-26:06:57:53,885 INFO     [task.py:395] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:03<00:00, 65.92it/s]
# 2024-03-26:06:57:56,899 INFO     [task.py:395] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:01<00:00, 66.40it/s]
# 2024-03-26:06:57:58,410 INFO     [task.py:395] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:02<00:00, 66.13it/s]
# 2024-03-26:06:58:01,035 INFO     [task.py:395] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:02<00:00, 65.62it/s]
# 2024-03-26:06:58:03,574 INFO     [task.py:395] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:04<00:00, 65.98it/s]
# 2024-03-26:06:58:07,603 INFO     [task.py:395] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:01<00:00, 65.68it/s]
# 2024-03-26:06:58:09,131 INFO     [task.py:395] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:03<00:00, 60.34it/s]
# 2024-03-26:06:58:12,838 INFO     [task.py:395] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:03<00:00, 64.74it/s]
# 2024-03-26:06:58:16,463 INFO     [task.py:395] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:04<00:00, 64.81it/s]
# 2024-03-26:06:58:20,828 INFO     [task.py:395] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:11<00:00, 65.40it/s]
# 2024-03-26:06:58:32,836 INFO     [task.py:395] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:01<00:00, 66.05it/s]
# 2024-03-26:06:58:34,401 INFO     [task.py:395] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:04<00:00, 65.43it/s]
# 2024-03-26:06:58:39,092 INFO     [task.py:395] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:04<00:00, 65.67it/s]
# 2024-03-26:06:58:43,247 INFO     [task.py:395] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:01<00:00, 66.02it/s]
# 2024-03-26:06:58:44,767 INFO     [task.py:395] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:02<00:00, 65.88it/s]
# 2024-03-26:06:58:46,823 INFO     [task.py:395] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 65.37it/s]
# 2024-03-26:06:58:50,138 INFO     [task.py:395] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 65.51it/s]
# 2024-03-26:06:58:52,359 INFO     [task.py:395] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 65.60it/s]
# 2024-03-26:06:58:53,889 INFO     [task.py:395] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 65.84it/s]
# 2024-03-26:06:58:55,595 INFO     [task.py:395] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 66.01it/s]
# 2024-03-26:06:58:57,115 INFO     [task.py:395] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 65.95it/s]
# 2024-03-26:06:58:58,637 INFO     [task.py:395] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 65.36it/s]
# 2024-03-26:06:59:00,204 INFO     [task.py:395] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 65.23it/s]
# 2024-03-26:06:59:02,527 INFO     [task.py:395] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:03<00:00, 66.03it/s]
# 2024-03-26:06:59:05,611 INFO     [task.py:395] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:04<00:00, 66.12it/s]
# 2024-03-26:06:59:09,707 INFO     [task.py:395] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 65.60it/s]
# 2024-03-26:06:59:11,237 INFO     [task.py:395] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 65.62it/s]
# 2024-03-26:06:59:13,439 INFO     [task.py:395] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 66.25it/s]
# 2024-03-26:06:59:15,741 INFO     [task.py:395] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.09it/s]
# 2024-03-26:06:59:17,260 INFO     [task.py:395] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 65.94it/s]
# 2024-03-26:06:59:23,010 INFO     [task.py:395] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 65.63it/s]
# 2024-03-26:06:59:24,539 INFO     [task.py:395] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 65.94it/s]
# 2024-03-26:06:59:29,255 INFO     [task.py:395] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 66.29it/s]
# 2024-03-26:06:59:32,811 INFO     [evaluator.py:379] Running loglikelihood requests
# Running loglikelihood requests: 100% 56168/56168 [05:39<00:00, 165.34it/s]
# hf (pretrained=EleutherAI/pythia-1.4b), gen_kwargs: (None), limit: None, num_fewshot: 5, batch_size: 8
# |                 Tasks                 |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |---------------------------------------|-------|------|-----:|------|-----:|---|-----:|
# |mmlu                                   |N/A    |none  |     0|acc   |0.2574|±  |0.0037|
# | - humanities                          |N/A    |none  |     5|acc   |0.2621|±  |0.0064|
# |  - formal_logic                       |      0|none  |     5|acc   |0.1270|±  |0.0298|
# |  - high_school_european_history       |      0|none  |     5|acc   |0.2667|±  |0.0345|
# |  - high_school_us_history             |      0|none  |     5|acc   |0.2892|±  |0.0318|
# |  - high_school_world_history          |      0|none  |     5|acc   |0.2574|±  |0.0285|
# |  - international_law                  |      0|none  |     5|acc   |0.3306|±  |0.0429|
# |  - jurisprudence                      |      0|none  |     5|acc   |0.2593|±  |0.0424|
# |  - logical_fallacies                  |      0|none  |     5|acc   |0.3067|±  |0.0362|
# |  - moral_disputes                     |      0|none  |     5|acc   |0.2775|±  |0.0241|
# |  - moral_scenarios                    |      0|none  |     5|acc   |0.2469|±  |0.0144|
# |  - philosophy                         |      0|none  |     5|acc   |0.2894|±  |0.0258|
# |  - prehistory                         |      0|none  |     5|acc   |0.2438|±  |0.0239|
# |  - professional_law                   |      0|none  |     5|acc   |0.2601|±  |0.0112|
# |  - world_religions                    |      0|none  |     5|acc   |0.2924|±  |0.0349|
# | - other                               |N/A    |none  |     5|acc   |0.2594|±  |0.0079|
# |  - business_ethics                    |      0|none  |     5|acc   |0.2200|±  |0.0416|
# |  - clinical_knowledge                 |      0|none  |     5|acc   |0.2453|±  |0.0265|
# |  - college_medicine                   |      0|none  |     5|acc   |0.2486|±  |0.0330|
# |  - global_facts                       |      0|none  |     5|acc   |0.3600|±  |0.0482|
# |  - human_aging                        |      0|none  |     5|acc   |0.3049|±  |0.0309|
# |  - management                         |      0|none  |     5|acc   |0.2816|±  |0.0445|
# |  - marketing                          |      0|none  |     5|acc   |0.2607|±  |0.0288|
# |  - medical_genetics                   |      0|none  |     5|acc   |0.2200|±  |0.0416|
# |  - miscellaneous                      |      0|none  |     5|acc   |0.2733|±  |0.0159|
# |  - nutrition                          |      0|none  |     5|acc   |0.2549|±  |0.0250|
# |  - professional_accounting            |      0|none  |     5|acc   |0.2589|±  |0.0261|
# |  - professional_medicine              |      0|none  |     5|acc   |0.1765|±  |0.0232|
# |  - virology                           |      0|none  |     5|acc   |0.2831|±  |0.0351|
# | - social_sciences                     |N/A    |none  |     5|acc   |0.2434|±  |0.0077|
# |  - econometrics                       |      0|none  |     5|acc   |0.2193|±  |0.0389|
# |  - high_school_geography              |      0|none  |     5|acc   |0.2222|±  |0.0296|
# |  - high_school_government_and_politics|      0|none  |     5|acc   |0.1865|±  |0.0281|
# |  - high_school_macroeconomics         |      0|none  |     5|acc   |0.2231|±  |0.0211|
# |  - high_school_microeconomics         |      0|none  |     5|acc   |0.2227|±  |0.0270|
# |  - high_school_psychology             |      0|none  |     5|acc   |0.2514|±  |0.0186|
# |  - human_sexuality                    |      0|none  |     5|acc   |0.2595|±  |0.0384|
# |  - professional_psychology            |      0|none  |     5|acc   |0.2778|±  |0.0181|
# |  - public_relations                   |      0|none  |     5|acc   |0.3091|±  |0.0443|
# |  - security_studies                   |      0|none  |     5|acc   |0.1959|±  |0.0254|
# |  - sociology                          |      0|none  |     5|acc   |0.2587|±  |0.0310|
# |  - us_foreign_policy                  |      0|none  |     5|acc   |0.2900|±  |0.0456|
# | - stem                                |N/A    |none  |     5|acc   |0.2620|±  |0.0078|
# |  - abstract_algebra                   |      0|none  |     5|acc   |0.2700|±  |0.0446|
# |  - anatomy                            |      0|none  |     5|acc   |0.3185|±  |0.0402|
# |  - astronomy                          |      0|none  |     5|acc   |0.2434|±  |0.0349|
# |  - college_biology                    |      0|none  |     5|acc   |0.3056|±  |0.0385|
# |  - college_chemistry                  |      0|none  |     5|acc   |0.2400|±  |0.0429|
# |  - college_computer_science           |      0|none  |     5|acc   |0.2800|±  |0.0451|
# |  - college_mathematics                |      0|none  |     5|acc   |0.2400|±  |0.0429|
# |  - college_physics                    |      0|none  |     5|acc   |0.2157|±  |0.0409|
# |  - computer_security                  |      0|none  |     5|acc   |0.2300|±  |0.0423|
# |  - conceptual_physics                 |      0|none  |     5|acc   |0.3106|±  |0.0303|
# |  - electrical_engineering             |      0|none  |     5|acc   |0.2552|±  |0.0363|
# |  - elementary_mathematics             |      0|none  |     5|acc   |0.2698|±  |0.0229|
# |  - high_school_biology                |      0|none  |     5|acc   |0.2581|±  |0.0249|
# |  - high_school_chemistry              |      0|none  |     5|acc   |0.2562|±  |0.0307|
# |  - high_school_computer_science       |      0|none  |     5|acc   |0.2900|±  |0.0456|
# |  - high_school_mathematics            |      0|none  |     5|acc   |0.2519|±  |0.0265|
# |  - high_school_physics                |      0|none  |     5|acc   |0.2450|±  |0.0351|
# |  - high_school_statistics             |      0|none  |     5|acc   |0.2454|±  |0.0293|
# |  - machine_learning                   |      0|none  |     5|acc   |0.2054|±  |0.0383|
#
# |      Groups      |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |------------------|-------|------|-----:|------|-----:|---|-----:|
# |mmlu              |N/A    |none  |     0|acc   |0.2574|±  |0.0037|
# | - humanities     |N/A    |none  |     5|acc   |0.2621|±  |0.0064|
# | - other          |N/A    |none  |     5|acc   |0.2594|±  |0.0079|
# | - social_sciences|N/A    |none  |     5|acc   |0.2434|±  |0.0077|
# | - stem           |N/A    |none  |     5|acc   |0.2620|±  |0.0078|

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-1.4b \
    --tasks ai2_arc \
    --device cuda:0 \
    --batch_size 8

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-1.4b  \
    --tasks winogrande \
    --device cuda:0 \
    --batch_size 8

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-1.4b  \
    --tasks lambada \
    --device cuda:0 \
    --batch_size 8

# %%
# !lm_eval --model hf \
    --model_args pretrained=EleutherAI/pythia-1.4b \
    --tasks hellaswag \
    --device cuda:0 \
    --batch_size 8
