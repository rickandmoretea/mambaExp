    1742.5709203192646, 1742.2959203192646, 1742.9916975339236, 1742.6849203192646, 1742.2259203192646, 1742.9563294498022, 1742.6667782143478, 1742.2163294498022, 1742.9029203192646, 1742.5917782143478
]

mamaba_time_per_epoch = [
    1995.3363194465637, 1993.5751330852509, 1993.5675339698792, 1993.2932331562042, 1993.2398383617401, 1993.7854321002396, 1993.4469082355499, 1994.0931944847107, 1994.6778941307068, 1995.0391435623175,
    1994.4567375183105, 1994.8831169605255, 1993.9681992530823, 1994.2314245700836, 1993.3610117435455, 1993.9173419475555, 1994.3452870845795, 1993.9971034526825, 1993.8683276176453, 1993.4709432125092,
    1994.2304944992065, 1993.5760626792908, 1994.2710988521576, 1994.1024787425995, 1993.7242922782898, 1994.1708590984344, 1994.3621671199799, 1993.5390245914465, 1993.4976129531862, 1994.5215852260599,
    1993.6233990192413, 1994.0806236267093, 1993.7188842296645, 1994.1063513755798, 1994.5186228752136, 1993.5080597400665, 1993.5860881805427, 1994.1557288169864, 1993.4327914714813, 1993.5649671554565,
    1994.1578278541565, 1993.7553820610046, 1994.1952090263367, 1993.6332764625559, 1993.8850522041342, 1994.1891036033635, 1993.6703636646272, 1993.9521615505215, 1993.4646732807162, 1994.2894482612612,
    1993.7149958610535, 1993.7802836894989, 1994.0877158641815, 1993.5603981018066, 1993.9992582798004, 1994.0620429515839, 1993.9167759418488, 1994.3879008293152, 1994.3734204769135, 1993.7436842918396,
    1994.3445904254913, 1993.8863561153412, 1994.0141096115112, 1993.9250526428223, 1994.3437418937683, 1993.7822163105017, 1994.1857154369354, 1993.6900138854985, 1993.9564800262454, 1994.1010675430298,
    1993.9834852218628, 1993.9601961371117, 1993.8943145275116, 1993.9208600521088, 1993.8657333850862, 1993.8664827346248, 1994.0164959430695, 1993.9283697605133, 1994.0859003067017, 1993.8775296211243,
    1993.8548977375030, 1993.7771298284535, 1994.0364017486572, 1993.6824340820327, 1994.1664953231812, 1993.9434204101562, 1993.7818231582642, 1993.8908214569092, 1993.9324474334717, 1993.9085865020752,
    1993.7771165370942, 1994.0017752647433, 1994.1799991130835, 1993.9914627075195, 1993.8022778034218, 1993.9415729045868, 1994.0033881664276, 1994.1625771522522, 1994.1434557437897, 1993.9864404201508,
]

plt.figure(figsize=(10, 6))
plt.plot(transformer_epochs, transformer_time_per_epoch, marker='o', linestyle='-', color='blue', label='Transformer Model')
plt.plot(transformer_epochs, mamaba_time_per_epoch, marker='o', linestyle='-', color='green', label='Mamaba Model')
plt.title('Time per Epoch for Transformer and Mamaba Models (100 Epochs)')
plt.xlabel('Epoch')
plt.ylabel('Time (seconds)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
average_time_per_epoch_transformer = sum(transformer_time_per_epoch) / len(transformer_time_per_epoch)
average_time_per_epoch_transformer
# Out:
# 1742.552992760301

# %%
average_time_per_epoch_mamba = sum(mamaba_time_per_epoch) / len(mamaba_time_per_epoch)
average_time_per_epoch_mamba
# Out:
# 1993.9625752575644

# %% [markdown]
# Based on these calculations, the transformer model has a lower average time per epoch compared to the Mamba model, indicating that it is more efficient in terms of time per epoch and this is because mamba is slower at training but faster at inference.

# %% [markdown]
# # Chart memory usage in a bar graph (mamba vs transfromer)

# %%
epochs = range(1, 101)

memory_usage_mamba = [
    1693.80, 1693.80, 1693.80, 1693.79, 1693.78, 1693.78, 1693.78, 1693.78, 1693.79, 1693.79,
    1693.79, 1693.79, 1693.79, 1693.72, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79,
    1693.79, 1693.79, 1693.79, 1693.79, 1693.75, 1693.74, 1693.74, 1693.74, 1693.76, 1693.77,
    1693.77, 1693.77, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79,
    1693.79, 1693.79, 1693.74, 1693.74, 1693.73, 1693.73, 1693.73, 1693.73, 1693.73, 1693.72,
    1693.75, 1693.77, 1693.77, 1693.77, 1693.77, 1693.76, 1693.76, 1693.77, 1693.75, 1693.79,
    1693.73, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79, 1693.79,
    1693.74, 1693.74, 1693.79, 1693.79, 1693.79, 1693.79, 1693.72, 1693.72, 1693.72, 1693.71,
    1693.76, 1693.78, 1693.73, 1693.76, 1693.76, 1693.79, 1693.76, 1693.72, 1693.74, 1693.76,
    1693.78, 1693.73, 1693.73, 1693.73, 1693.76, 1693.77, 1693.77, 1693.77, 1693.76, 1693.77,

]

memory_usage_transformers = [
    3615.70, 4079.72, 4097.83, 4134.56, 4172.21, 4207.55, 4245.10, 4279.36, 4314.25, 4350.11,
    4382.21, 4414.89, 4448.42, 4481.12, 4515.67, 4547.47, 4579.91, 4612.57, 4643.47, 4673.90,
    4705.90, 4736.82, 4766.66, 4797.56, 4827.81, 4857.74, 4887.68, 4918.58, 4949.09, 4980.43,
    5011.57, 5042.59, 5072.46, 5102.93, 5132.82, 5162.68, 5193.27, 5223.03, 5252.87, 5283.58,
    5313.47, 5343.29, 5374.15, 5403.99, 5433.83, 5463.78, 5493.59, 5523.32, 5553.09, 5582.89,
    5612.70, 5643.36, 5673.28, 5703.22, 5733.03, 5762.78, 5792.59, 5822.45, 5852.33, 5882.20,
    5912.03, 5941.80, 5971.65, 6001.43, 6031.24, 6061.01, 6090.85, 6120.69, 6149.72, 6179.46,
    6209.25, 6239.04, 6268.75, 6298.59, 6328.35, 6358.13, 6387.90, 6417.69, 6447.40, 6477.23,
    6507.03, 6536.74, 6566.55, 6596.29, 6626.11, 6655.91, 6685.74, 6715.45, 6745.29, 6775.10,
    6804.95, 6834.73, 6864.54, 6894.30, 6924.09, 6953.90, 6983.73, 7013.49, 7043.29, 7073.10
]

plt.figure(figsize=(10, 6))
plt.bar(epochs, memory_usage_mamba, label='Mamba Memory Usage', alpha=0.7)
plt.bar(epochs, memory_usage_transformers, label='Transformers Memory Usage', alpha=0.7)
plt.xlabel('Epochs')
plt.ylabel('Memory Usage (MB)')
plt.title('Memory Usage Comparison between Mamba and Transformers')
plt.legend()
plt.grid(True)
plt.show()

# %%
average_memory_mamba = sum(memory_usage_mamba) / len(memory_usage_mamba)
average_memory_mamba
# Out:
# 1693.7680999999993

# %%
average_memory_transformers = sum(memory_usage_transformers) / len(memory_usage_transformers)
average_memory_transformers
# Out:
# 5583.579699999999

# %% [markdown]
# Based on these calculations, Mamba has a significantly lower average memory usage compared to Transformers. Therefore, in terms of memory efficiency, Mamba appears to be the better option.
